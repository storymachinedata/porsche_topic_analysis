# %%
import pandas as pd
from googletrans import Translator

# %%
porsche_insta_df = pd.read_csv("./data/porsche_raw_instagram_dataset.csv")
bmw_insta_df = pd.read_csv("./data/bmw_raw_instagram_dataset.csv")
mercedes_insta_df = pd.read_csv("./data/mercedes_raw_instagram_dataset.csv")

# %%
print(porsche_insta_df.shape)
print(bmw_insta_df.shape)
print(mercedes_insta_df.shape)
# Out:
# (1268, 54)
# (1000, 30)
# (1000, 58)

# %%
bmw_insta_df.head()
# Out:
#                                     postUrl  \
# 0  https://www.instagram.com/p/Cyi54MaMxlQ/
# 1  https://www.instagram.com/p/CyipkWZulk0/
# 2  https://www.instagram.com/p/CygGbSOuk5_/
# 3  https://www.instagram.com/p/CyWBBrqO_vy/
# 4  https://www.instagram.com/p/CyV4SCJtjFp/
#
#                                          description  commentCount  likeCount  \
# 0  Last call! Our Oktoberfest West is happening i...             1        113
# 1  The #SpiritofGS was alive last weekend and we’...             2        220
# 2  Ride in a BMW racecar! Our M Fall Festival eve...             3        202
# 3  BMW + the ExtremeContact Sport 02 = Extreme Pe...             3        304
# 4  It’s time to celebrate at Thermal! We’re hosti...             3        298
#
#                     pubDate  isSidecar   type  \
# 0  2023-10-18T15:35:08.000Z      False  Photo
# 1  2023-10-18T13:15:03.000Z      False  Video
# 2  2023-10-17T13:27:03.000Z      False  Photo
# 3  2023-10-13T15:29:16.000Z      False  Video
# 4  2023-10-13T14:11:03.000Z      False  Photo
#
#                                              caption  \
# 0  Photo by BMW Performance Driving School on Oct...
# 1                                                NaN
# 2  Photo by BMW Performance Driving School on Oct...
# 3                                                NaN
# 4  Photo by BMW Performance Driving School on Oct...
#
#                                           profileUrl  \
# 0  https://www.instagram.com/bmwperformancedrivin...
# 1           https://www.instagram.com/bmwmotorradusa
# 2  https://www.instagram.com/bmwperformancedrivin...
# 3         https://www.instagram.com/continental_tire
# 4  https://www.instagram.com/bmwperformancedrivin...
#
#                        username  ...       taggedFullName2    taggedUsername2  \
# 0  bmwperformancedrivingschools  ...                   NaN                NaN
# 1                bmwmotorradusa  ...  BMW US Rider Academy  bmwusrideracademy
# 2  bmwperformancedrivingschools  ...                   NaN                NaN
# 3              continental_tire  ...                   NaN                NaN
# 4  bmwperformancedrivingschools  ...                   NaN                NaN
#
#   likedByViewer fullName videoDuration  playCount taggedFullName3  \
# 0           NaN      NaN           NaN        NaN             NaN
# 1           NaN      NaN           NaN        NaN             NaN
# 2           NaN      NaN           NaN        NaN             NaN
# 3           NaN      NaN           NaN        NaN             NaN
# 4           NaN      NaN           NaN        NaN             NaN
#
#    taggedUsername3 taggedFullName4 taggedUsername4
# 0              NaN             NaN             NaN
# 1              NaN             NaN             NaN
# 2              NaN             NaN             NaN
# 3              NaN             NaN             NaN
# 4              NaN             NaN             NaN
#
# [5 rows x 30 columns]

# %%
porsche_insta_df.head()
# Out:
#                                     postUrl  \
# 0  https://www.instagram.com/p/CpubRP2oX3X/
# 1  https://www.instagram.com/p/Ch4jE_4ogCh/
# 2  https://www.instagram.com/p/Cfd5SLpIRhS/
# 3  https://www.instagram.com/p/CyixwV1CUPf/
# 4  https://www.instagram.com/p/Cydwscsr2M3/
#
#                                          description  commentCount  likeCount  \
# 0  Adrenalinjäger aufgepasst: Am 18. März trifft ...             4        413
# 1  Erfülle Dir Deinen Traum mit unseren Fahrerleb...             0        425
# 2  Die Rennstrecke ruft! Seid Ihr bereit, Euch de...             2        285
# 3  Die sicherste Strategie für eine entspannte We...             0        126
# 4  Perfektes Wetter und ein spektakuläres Program...             2        234
#
#                                    location    locationId  \
# 0  Porsche Experience Center Hockenheimring  1.068808e+14
# 1  Porsche Experience Center Hockenheimring  1.068808e+14
# 2  Porsche Experience Center Hockenheimring  1.068808e+14
# 3                                       NaN           NaN
# 4                                       NaN           NaN
#
#                     pubDate  isSidecar   type  \
# 0  2023-03-13T10:15:59.000Z      False  Photo
# 1  2022-08-30T12:28:31.000Z      False  Video
# 2  2022-07-01T10:57:13.000Z      False  Photo
# 3  2023-10-18T14:24:08.000Z      False  Photo
# 4  2023-10-16T15:38:39.000Z       True  Photo
#
#                                              caption  ... taggedFullName12  \
# 0  Photo by PEC Hockenheimring in Porsche Experie...  ...              NaN
# 1                                                NaN  ...              NaN
# 2  Photo by PEC Hockenheimring in Porsche Experie...  ...              NaN
# 3  Photo by PEC Hockenheimring on October 18, 202...  ...              NaN
# 4  Photo by PEC Hockenheimring on October 16, 202...  ...              NaN
#
#   taggedUsername12 taggedFullName13 taggedUsername13 taggedFullName14  \
# 0              NaN              NaN              NaN              NaN
# 1              NaN              NaN              NaN              NaN
# 2              NaN              NaN              NaN              NaN
# 3              NaN              NaN              NaN              NaN
# 4              NaN              NaN              NaN              NaN
#
#   taggedUsername14 taggedFullName15  taggedUsername15 taggedFullName16  \
# 0              NaN              NaN               NaN              NaN
# 1              NaN              NaN               NaN              NaN
# 2              NaN              NaN               NaN              NaN
# 3              NaN              NaN               NaN              NaN
# 4              NaN              NaN               NaN              NaN
#
#   taggedUsername16
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
#
# [5 rows x 54 columns]

# %%
def drop_unecessary_columns(df: pd.DataFrame):
    
    column_list = [
        'location','locationId', "isSidecar", "query",
         "videoUrl", "timestamp",'likedByViewer', "imgUrl",
        'fullName', 'videoDuration', "caption", "postId"]
    df = df.drop(columns=column_list, axis=1)
    df = df.loc[:,~df.columns.str.startswith("tagged")]
    return df

def rename_columns(df: pd.DataFrame):
    rename_cols = {
        "description": "postContent",
        "pubDate": "postTimestamp"
    }
    return df.rename(columns=rename_cols)

def change_datatypes(df: pd.DataFrame):
    df["postTimestamp"] = pd.to_datetime(df["postTimestamp"])
    return df

def get_current_year_data(df: pd.DataFrame, year: int):
    return df[df["postTimestamp"] >= f"{year}.01.01"].sort_values("postTimestamp")

# %%
def pipeline(df: pd.DataFrame):
    df = drop_unecessary_columns(df=df)
    df = rename_columns(df=df)
    df = change_datatypes(df=df)
    df = get_current_year_data(df=df, year=2023)
    return df

# %%
porsche_df = pipeline(df=porsche_insta_df)
bmw_df = pipeline(df=bmw_insta_df)
mercedes_df = pipeline(df=mercedes_insta_df)

# %% [markdown]
# ## Splitting the text (Porsche)

# %%
porsche_df.head()
# Out:
#                                       postUrl  \
# 414  https://www.instagram.com/p/Cm6QO3Uoz-A/
# 413  https://www.instagram.com/p/Cm6QO3Uoz-A/
# 411  https://www.instagram.com/p/CnAKVbkNMQG/
# 412  https://www.instagram.com/p/CnAKVbkNMQG/
# 410  https://www.instagram.com/p/CnAKVbkNMQG/
#
#                                            postContent  commentCount  \
# 414  Das neue Jahr hat begonnen und wir können es s...             2
# 413  Das neue Jahr hat begonnen und wir können es s...             2
# 411  Eines der großen Highlights, die 2023 auf Euch...             1
# 412  Eines der großen Highlights, die 2023 auf Euch...             1
# 410  Eines der großen Highlights, die 2023 auf Euch...             1
#
#      likeCount             postTimestamp   type  \
# 414        298 2023-01-02 10:56:14+00:00  Photo
# 413        298 2023-01-02 10:56:14+00:00  Photo
# 411        210 2023-01-04 18:00:09+00:00  Photo
# 412        210 2023-01-04 18:00:09+00:00  Photo
# 410        210 2023-01-04 18:00:09+00:00  Photo
#
#                             profileUrl username  viewCount  playCount
# 414  https://www.instagram.com/pec.hhr  pec.hhr        NaN        NaN
# 413  https://www.instagram.com/pec.hhr  pec.hhr        NaN        NaN
# 411  https://www.instagram.com/pec.hhr  pec.hhr        NaN        NaN
# 412  https://www.instagram.com/pec.hhr  pec.hhr        NaN        NaN
# 410  https://www.instagram.com/pec.hhr  pec.hhr        NaN        NaN

# %%
filtered_content_en = []
filtered_content_de = []
translator = Translator()

for i in range(len(porsche_df)):
    text = porsche_df.postContent.values[i].split("\n")[0]
    filtered_content_de.append(text)
    text = translator.translate(text).text
    filtered_content_en.append(text)

# %%
porsche_df["filteredContentEn"] = filtered_content_en
porsche_df["filteredContentDe"] = filtered_content_de

# %% [markdown]
# ## Saving preprocessed DF

# %%
porsche_df.to_csv("./data/porsche_instagram.csv")
# bmw_df.to_csv("./data/bmw_instagram.csv")
# mercedes_df.to_csv("./data/mercedes_instagram.csv")
# Out:
# /Users/kaushikdayalan/projects/storymachine_projects/porsche_topic_analysis/.env/lib/python3.9/site-packages/pandas/core/internals/blocks.py:2540: RuntimeWarning: invalid value encountered in cast
#   values = values.astype(str)
